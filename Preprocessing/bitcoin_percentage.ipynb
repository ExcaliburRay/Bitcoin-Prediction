# %%
import pandas as pd

headers = ['Timestamp','Date','Symbol','Open','High','Low','Close','Volume']
bitcoin = pd.read_csv('/Users/katesxiao/Documents/M19/IS/Data/raw_bitcoin.csv',names=headers)
bitcoin=bitcoin.drop([0,1,2])

# %%
bitcoin['Date']=pd.to_datetime(bitcoin['Date'], format='%d/%m/%y %H:%M')
bitcoin = bitcoin.sort_values(by = 'Date', ascending = True)
bitcoin = bitcoin.reset_index(drop = True)
bitcoin
# Out:
#          Timestamp                Date  Symbol     Open     High      Low  \
# 0       1444309200 2015-10-08 13:00:00  BTCUSD        0      245        0
# 1       1444312800 2015-10-08 14:00:00  BTCUSD      245      245    244.5
# 2       1444316400 2015-10-08 15:00:00  BTCUSD      245      245   244.92
# 3       1444320000 2015-10-08 16:00:00  BTCUSD   244.92   244.92   244.25
# 4       1444323600 2015-10-08 17:00:00  BTCUSD   244.25   244.99   244.02
# 5       1444327200 2015-10-08 18:00:00  BTCUSD   244.99   244.99      244
# 6       1444330800 2015-10-08 19:00:00  BTCUSD      244      244      244
# 7       1444334400 2015-10-08 20:00:00  BTCUSD      244      244    243.6
# 8       1444338000 2015-10-08 21:00:00  BTCUSD      244      244   243.95
# 9       1444341600 2015-10-08 22:00:00  BTCUSD   243.95      244    243.8
# 10      1444345200 2015-10-08 23:00:00  BTCUSD   243.95   243.95   243.72
# 11      1444348800 2015-10-09 00:00:00  BTCUSD   243.95   243.95    243.6
# ...

# %%
bitcoin['Close'] = bitcoin.Close.astype(float)
bitcoin.dtypes
# Out:
# Timestamp            object
# Date         datetime64[ns]
# Symbol               object
# Open                 object
# High                 object
# Low                  object
# Close               float64
# Volume               object
# dtype: object

# %%
start = bitcoin.iloc[0]['Date']
end = bitcoin.iloc[-1]['Date']
print(start)
print(end)
print(start + (end-start) * 0.7)
# Out:
# 2015-10-08 13:00:00
# 2019-05-27 00:00:00
# 2018-04-24 01:30:00

# %%
bitcoin.shape
# Out:
# (31836, 8)

# %%
Price = list(bitcoin['Close'])
Price = Price[6:]
Price.append(1)
Price.append(1)
Price.append(1)
Price.append(1)
Price.append(1)
Price.append(1)
Price
# Out:
# [244.0,
#  244.0,
#  243.95,
#  243.95,
#  243.95,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.6,
#  243.63,
#  243.63,
#  244.0,
#  244.0,
#  244.0,
#  244.0,
#  243.7,
#  243.7,
#  244.06,
#  249.97,
#  245.39,
#  245.39,
#  245.39,
#  245.39,
#  245.54,
#  245.51,
#  245.51,
#  245.45,
#  245.45,
#  245.45,
#  245.45,
#  245.45,
#  245.45,
#  245.45,
#  244.6,
#  244.6,
#  245.18,
#  245.18,
#  245.37,
#  245.37,
#  245.37,
#  245.37,
#  245.37,
#  245.37,
#  245.75,
#  245.75,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.3,
#  246.5,
#  248.24,
#  248.24,
#  248.24,
#  248.24,
#  247.77,
#  248.24,
#  249.5,
#  249.0,
#  249.0,
#  249.0,
#  248.98,
#  248.71,
#  248.71,
#  248.71,
#  248.71,
#  248.71,
#  248.71,
#  248.71,
#  247.72,
#  247.72,
#  247.62,
#  247.62,
#  247.62,
#  247.91,
# ...

# %%
bitcoin['Six_Hours'] = Price
bitcoin
# Out:
#          Timestamp                Date  Symbol     Open     High      Low  \
# 0       1444309200 2015-10-08 13:00:00  BTCUSD        0      245        0
# 1       1444312800 2015-10-08 14:00:00  BTCUSD      245      245    244.5
# 2       1444316400 2015-10-08 15:00:00  BTCUSD      245      245   244.92
# 3       1444320000 2015-10-08 16:00:00  BTCUSD   244.92   244.92   244.25
# 4       1444323600 2015-10-08 17:00:00  BTCUSD   244.25   244.99   244.02
# 5       1444327200 2015-10-08 18:00:00  BTCUSD   244.99   244.99      244
# 6       1444330800 2015-10-08 19:00:00  BTCUSD      244      244      244
# 7       1444334400 2015-10-08 20:00:00  BTCUSD      244      244    243.6
# 8       1444338000 2015-10-08 21:00:00  BTCUSD      244      244   243.95
# 9       1444341600 2015-10-08 22:00:00  BTCUSD   243.95      244    243.8
# 10      1444345200 2015-10-08 23:00:00  BTCUSD   243.95   243.95   243.72
# 11      1444348800 2015-10-09 00:00:00  BTCUSD   243.95   243.95    243.6
# ...

# %%
bitcoin = bitcoin.head(31830)
bitcoin['Percentage'] = (bitcoin['Six_Hours'] - bitcoin['Close'])/bitcoin['Close']
bitcoin
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#          Timestamp                Date  Symbol     Open     High      Low  \
# 0       1444309200 2015-10-08 13:00:00  BTCUSD        0      245        0
# 1       1444312800 2015-10-08 14:00:00  BTCUSD      245      245    244.5
# 2       1444316400 2015-10-08 15:00:00  BTCUSD      245      245   244.92
# 3       1444320000 2015-10-08 16:00:00  BTCUSD   244.92   244.92   244.25
# 4       1444323600 2015-10-08 17:00:00  BTCUSD   244.25   244.99   244.02
# 5       1444327200 2015-10-08 18:00:00  BTCUSD   244.99   244.99      244
# ...

# %%
bitcoin.to_csv('/Users/katesxiao/Documents/M19/IS/Data/bitcoin_percentage.csv', index = False)
